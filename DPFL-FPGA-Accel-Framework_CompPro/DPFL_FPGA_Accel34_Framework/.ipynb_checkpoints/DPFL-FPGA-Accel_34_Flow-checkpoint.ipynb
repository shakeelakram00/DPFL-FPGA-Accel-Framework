# %%
#Replace {Pass} with FPGA board Password
# !echo {Pass} | sudo -S python3.8 ./DPFL_Accel_5Ectopic_main.py --epochs=5 --num_users=2 --frac=1. --local_ep=10 --local_bs=100 --virtual_batch_size=100 --optimizer='adam' --lr=0.001 --momentum=0.9 --dataset='5Ectopic' --dr_from_np=1 --withDP=1 --max_grad_norm=0.002 --noise_multiplier=1.30 --delta=1e-4 --local_test_split=0.2 --sampling_prob=0.19 #1.0
# Out:
# [sudo] password for xilinx: Model's already Valid!
#
# Avg Local batch_size:  3800
# Avg Global batch_size:  9500
# Processing Local Epoch(s): 100%|█| 200/200 [02:38<00:00,  1.26batch/s, batch=200
# Local Epoch:  1 Training Loss:  0.6209743902087211 Training Accuracy:80.8824%
# Validation Loss:  0.5430065111981498 Validation Accuracy:82.5816%
# Processing Local Epoch(s): 100%|█| 200/200 [02:40<00:00,  1.24batch/s, batch=200
# Local Epoch:  2 Training Loss:  0.5745268078148364 Training Accuracy:82.3484%
# Validation Loss:  0.5387306693527434 Validation Accuracy:83.2908%
# Processing Local Epoch(s): 100%|█| 200/200 [02:38<00:00,  1.26batch/s, batch=200
# Local Epoch:  3 Training Loss:  0.5220036131888628 Training Accuracy:83.6977%
# Validation Loss:  0.5366794301403893 Validation Accuracy:83.0071%
# Processing Local Epoch(s): 100%|█| 200/200 [02:36<00:00,  1.28batch/s, batch=200
# Local Epoch:  4 Training Loss:  0.5235798419266939 Training Accuracy:83.9778%
# ...
